# %%
import pandas as pd
crime=pd.read_csv('cprsvCAW_2_2014_1.csv')

# %%
crime
# Out:
#              States/UTs                           Crime Head  Year  \
# 0        Andhra Pradesh           1 - Rape (Section 376 IPC)  2014
# 1        Andhra Pradesh                 1.1 - Custodial Rape  2014
# 2        Andhra Pradesh          1.1.1 - Custodial_Gang Rape  2014
# 3        Andhra Pradesh         1.1.2 - Custodial_Other Rape  2014
# 4        Andhra Pradesh      1.2 - Rape other than Custodial  2014
# ...                 ...                                  ...   ...
# 1555  Total (All India)           14.2 - Under ITP Section 6  2014
# 1556  Total (All India)           14.3 - Under ITP Section 7  2014
# 1557  Total (All India)           14.4 - Under ITP Section 8  2014
# 1558  Total (All India)  14.5 - Other Sections under ITP Act  2014
# 1559  Total (All India)      15 - Total Crimes against Women  2014
#
#       Cases pending investigation from previous year  \
# 0                                                602
# ...

# %%
crime.describe()
# Out:
#          Year  Cases pending investigation from previous year  \
# count  1560.0                                     1560.000000
# mean   2014.0                                      630.505769
# std       0.0                                     4963.069119
# min    2014.0                                        0.000000
# 25%    2014.0                                        0.000000
# 50%    2014.0                                        1.000000
# 75%    2014.0                                       56.250000
# max    2014.0                                   123687.000000
#
#        Cases reported Under 156_3 during the year  \
# count                                 1560.000000
# mean                                   163.101923
# std                                   1706.848202
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      1.000000
# ...

# %%
crime.columns
# Out:
# Index(['States/UTs', 'Crime Head', 'Year',
#        'Cases pending investigation from previous year',
#        'Cases reported Under 156_3 during the year',
#        'Cases reported in Police Stations during the year',
#        'Cases reported during the year',
#        'No of victims in the registered cases',
#        'No of cases withdrawn by the Govt during investigation',
#        'Cases not investigated Under 157_1_b CRPC',
#        'Cases transferred to other Police Station or Magistrate',
#        'Cases ended as final report false',
#        'Cases ended as mistake of fact or of law',
#        'Cases in ended as final report as Non Cognizable Submitted',
#        'Cases Chargesheeted Out of Cases During the Year',
#        'Cases Chargesheeted Out of Cases from Previous Year',
#        'Cases Chargesheeted',
#        'Cases Not Chargesheeted but final report Submitted',
#        'Total cases Investigated',
#        'Cases pending investigation at the end of the year',
# ...

# %%
crime['Cases reported during the year'].sum()
# Out:
# 2701995

# %%
Crime_Head = crime.groupby('Crime Head')

# %%
print(Crime_Head.groups)
# Out:
# {'1 - Rape (Section 376 IPC)': Int64Index([   0,   40,   80,  120,  160,  200,  240,  280,  320,  360,  400,
#              440,  480,  520,  560,  600,  640,  680,  720,  760,  800,  840,
#              880,  920,  960, 1000, 1040, 1080, 1120, 1160, 1200, 1240, 1280,
#             1320, 1360, 1400, 1440, 1480, 1520],
#            dtype='int64'), '1.1 - Custodial Rape': Int64Index([   1,   41,   81,  121,  161,  201,  241,  281,  321,  361,  401,
#              441,  481,  521,  561,  601,  641,  681,  721,  761,  801,  841,
#              881,  921,  961, 1001, 1041, 1081, 1121, 1161, 1201, 1241, 1281,
#             1321, 1361, 1401, 1441, 1481, 1521],
#            dtype='int64'), '1.1.1 - Custodial_Gang Rape': Int64Index([   2,   42,   82,  122,  162,  202,  242,  282,  322,  362,  402,
#              442,  482,  522,  562,  602,  642,  682,  722,  762,  802,  842,
#              882,  922,  962, 1002, 1042, 1082, 1122, 1162, 1202, 1242, 1282,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x='States/UTs',y='Cases reported during the year',data=crime)

# %%
crime['Cases pending investigation at the end of the year'].sum()
# Out:
# 1160796

# %%
sns.barplot(x='States/UTs',y='Persons on bail during trial stage at Year End_Male',data=crime)

# %%
crime['Cases pending investigation at the end of the year'].sum()
# Out:
# 1160796

# %%
crime['Crime Head'].sum()
# Out:
# '1 - Rape (Section 376 IPC)1.1 - Custodial Rape1.1.1 - Custodial_Gang Rape1.1.2 - Custodial_Other Rape1.2 - Rape other than Custodial1.2.1 - Rape_Gang Rape1.2.2 - Rape_Others2 - Attempt to commit Rape (Section 376 & 511 IPC)3 - Kidnapping & Abduction of Women (Section 363,364,364A, 366-369 IPC)3.1 - Kidnaping & Abduction Section 363 IPC3.2 - Kidnaping & Abduction in order to Murder Section 364 IPC3.3 - Kidnapping for Ransom Section 364A3.4 - Kidnapping & Abduction of Women to compel her for marriage3.5 - Kidnapping & Abduction of Women-Other4 - Dowry Deaths (Section 304-B IPC)5 - Assault on Women with intent to outrage her Modesty_Total (Section 354 IPC)5.1 - Sexual Harassment5.2 - Assault on women with intent to Disrobe5.3 - Voyeurism5.4 - Stalking5.5 - Others6 - Insult to the Modesty of Women_Total (Section 509 IPC)6.1 - At Office premises6.2 - Other places related to work6.3 - In Public Transport system6.4 - in Other Places7 - Cruelty by Husband or his Relatives (Section 498A)8 - 
# ...
